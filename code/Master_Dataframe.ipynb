# %% [markdown]
# ## Compile fully cleaned, Master Dataframe with all available base regressors/classifiers

# %%
import pickle
import os
import time

import numpy as np
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### Load & Compile primary intraday data into one dataframe

# %%
fname_1 = r'\vx1_opt.pkl'
fname_2 = r'\vix_vol_2terms.pkl'
fname_3 = r'\spx_returns.pkl'

filepath = os.getcwd() + r'\Data\Intraday\Pickle'

vx1_opt = pickle.load(open(filepath + fname_1, "rb"))
vix_ivol = pickle.load(open(filepath + fname_2, "rb"))
spx_index = pickle.load(open(filepath + fname_3, "rb"))

# %% [markdown]
# #### Load SPX Options & VIX Futures data

# %%
vx1_opt.head()
# Out:
#                      Strike1  Strike2   Option1   Option2         t1  \
# 2015-01-02 09:40:00   2070.0   2070.0  0.132620  0.136980  11.993056
# 2015-01-02 09:50:00   2070.0   2070.0  0.132455  0.136215  11.986111
# 2015-01-02 10:00:00   2070.0   2065.0  0.134345  0.138615  11.979167
# 2015-01-02 10:10:00   2065.0   2060.0  0.139675  0.143980  11.972222
# 2015-01-02 10:20:00   2065.0   2060.0  0.140710  0.144930  11.965278
#
#                             t2  FWD_PRICE        OPT  VX1-OPT_Spread
# 2015-01-02 09:40:00  32.993056     17.175  13.940883        3.234117
# 2015-01-02 09:50:00  32.986111     17.275  13.831527        3.443473
# 2015-01-02 10:00:00  32.979167     17.375  14.099285        3.275715
# 2015-01-02 10:10:00  32.972222     17.725  14.637765        3.087235
# 2015-01-02 10:20:00  32.965278     17.725  14.728039        2.996961

# %% [markdown]
# #### Load VIX Options data

# %%
vix_ivol.tail()
# Out:
#                      Strike1  Strike2   Option1   Option2         t1  \
# TIMESTAMP
# 2016-12-30 15:20:00     16.0     18.0  1.004045  0.919635  11.756944
# 2016-12-30 15:30:00     15.0     17.0  0.930065  0.866925  11.750000
# 2016-12-30 15:40:00     16.0     17.0  1.011760  0.872300  11.743056
# 2016-12-30 15:50:00     16.0     18.0  1.025765  0.909335  11.736111
# 2016-12-30 16:00:00     16.0     18.0  1.012165  0.919310  11.729167
#
#                      trade_dates/expiry  Weight_Opt
# TIMESTAMP
# 2016-12-30 15:20:00                18.0    0.974769
# 2016-12-30 15:30:00                18.0    0.908141
# 2016-12-30 15:40:00                18.0    0.963283
# 2016-12-30 15:50:00                18.0    0.985248
# 2016-12-30 16:00:00                18.0    0.979816

# %% [markdown]
# #### Load SPX Cash data

# %%
spx_index.head()
# Out:
#                      UPRICE_BID  UPRICE_ASK  UPRICE_MID
# TIMESTAMP
# 2015-01-02 09:30:00     0.00000     0.00000     0.00000
# 2015-01-02 09:40:00  2072.14990  2072.14990  2072.14990
# 2015-01-02 09:50:00  2068.86011  2068.86011  2068.86011
# 2015-01-02 10:00:00  2068.50000  2068.50000  2068.50000
# 2015-01-02 10:10:00  2063.32007  2063.32007  2063.32007

# %% [markdown]
# #### Add Weighted Imp. vol of ATM front month VIX options to VIX futures prices & SPX options approximation to create MASTER dataframe

# %%
master_mid = vx1_opt.merge(vix_ivol.iloc[:,6].to_frame(), left_index=True, right_index=True)

# %%
master_mid.head()
# Out:
#                      Strike1  Strike2   Option1   Option2         t1  \
# 2015-01-02 09:40:00   2070.0   2070.0  0.132620  0.136980  11.993056
# 2015-01-02 09:50:00   2070.0   2070.0  0.132455  0.136215  11.986111
# 2015-01-02 10:00:00   2070.0   2065.0  0.134345  0.138615  11.979167
# 2015-01-02 10:10:00   2065.0   2060.0  0.139675  0.143980  11.972222
# 2015-01-02 10:20:00   2065.0   2060.0  0.140710  0.144930  11.965278
#
#                             t2  FWD_PRICE        OPT  VX1-OPT_Spread  \
# 2015-01-02 09:40:00  32.993056     17.175  13.940883        3.234117
# 2015-01-02 09:50:00  32.986111     17.275  13.831527        3.443473
# 2015-01-02 10:00:00  32.979167     17.375  14.099285        3.275715
# 2015-01-02 10:10:00  32.972222     17.725  14.637765        3.087235
# 2015-01-02 10:20:00  32.965278     17.725  14.728039        2.996961
#
#                      Weight_Opt
# 2015-01-02 09:40:00    1.144474
# 2015-01-02 09:50:00    1.140503
# 2015-01-02 10:00:00    1.142770
# 2015-01-02 10:10:00    1.183701
# 2015-01-02 10:20:00    1.183615

# %% [markdown]
# #### Rename specific columns

# %%
master_mid.rename(columns={'Strike1':'SPX_k1', 'Strike2':'SPX_k2', 'Option1':'SPX_ImpVol1', 'Option2':'SPX_ImpVol2',\
                           't1':'DaysTo_VX1_Expiry', 't2':'DaysTo_VX2_Expiry', 'FWD_PRICE':'VX1_Future',\
                           'Weight_Opt':'VIX_ImpVol'}, inplace=True)

# %%
master_mid.head()
# Out:
#                      SPX_k1  SPX_k2  SPX_ImpVol1  SPX_ImpVol2  \
# 2015-01-02 09:40:00  2070.0  2070.0     0.132620     0.136980
# 2015-01-02 09:50:00  2070.0  2070.0     0.132455     0.136215
# 2015-01-02 10:00:00  2070.0  2065.0     0.134345     0.138615
# 2015-01-02 10:10:00  2065.0  2060.0     0.139675     0.143980
# 2015-01-02 10:20:00  2065.0  2060.0     0.140710     0.144930
#
#                      DaysTo_VX1_Expiry  DaysTo_VX2_Expiry  VX1_Future  \
# 2015-01-02 09:40:00          11.993056          32.993056      17.175
# 2015-01-02 09:50:00          11.986111          32.986111      17.275
# 2015-01-02 10:00:00          11.979167          32.979167      17.375
# 2015-01-02 10:10:00          11.972222          32.972222      17.725
# 2015-01-02 10:20:00          11.965278          32.965278      17.725
#
#                            OPT  VX1-OPT_Spread  VIX_ImpVol
# 2015-01-02 09:40:00  13.940883        3.234117    1.144474
# 2015-01-02 09:50:00  13.831527        3.443473    1.140503
# 2015-01-02 10:00:00  14.099285        3.275715    1.142770
# 2015-01-02 10:10:00  14.637765        3.087235    1.183701
# 2015-01-02 10:20:00  14.728039        2.996961    1.183615

# %% [markdown]
# #### Add intraday SPX Index prices to *master*

# %%
master_mid = master_mid.merge(spx_index.iloc[:,2].to_frame(), left_index=True, right_index=True)

# %%
master_mid.head()
# Out:
#                      SPX_k1  SPX_k2  SPX_ImpVol1  SPX_ImpVol2  \
# 2015-01-02 09:40:00  2070.0  2070.0     0.132620     0.136980
# 2015-01-02 09:50:00  2070.0  2070.0     0.132455     0.136215
# 2015-01-02 10:00:00  2070.0  2065.0     0.134345     0.138615
# 2015-01-02 10:10:00  2065.0  2060.0     0.139675     0.143980
# 2015-01-02 10:20:00  2065.0  2060.0     0.140710     0.144930
#
#                      DaysTo_VX1_Expiry  DaysTo_VX2_Expiry  VX1_Future  \
# 2015-01-02 09:40:00          11.993056          32.993056      17.175
# 2015-01-02 09:50:00          11.986111          32.986111      17.275
# 2015-01-02 10:00:00          11.979167          32.979167      17.375
# 2015-01-02 10:10:00          11.972222          32.972222      17.725
# 2015-01-02 10:20:00          11.965278          32.965278      17.725
#
#                            OPT  VX1-OPT_Spread  VIX_ImpVol  UPRICE_MID
# 2015-01-02 09:40:00  13.940883        3.234117    1.144474  2072.14990
# 2015-01-02 09:50:00  13.831527        3.443473    1.140503  2068.86011
# 2015-01-02 10:00:00  14.099285        3.275715    1.142770  2068.50000
# 2015-01-02 10:10:00  14.637765        3.087235    1.183701  2063.32007
# 2015-01-02 10:20:00  14.728039        2.996961    1.183615  2063.04004

# %% [markdown]
# #### Rename last column

# %%
master_mid.rename(columns={'UPRICE_MID':'SPX_Index(fwd)'}, inplace=True)

# %%
master_mid.head()
# Out:
#                      SPX_k1  SPX_k2  SPX_ImpVol1  SPX_ImpVol2  \
# 2015-01-02 09:40:00  2070.0  2070.0     0.132620     0.136980
# 2015-01-02 09:50:00  2070.0  2070.0     0.132455     0.136215
# 2015-01-02 10:00:00  2070.0  2065.0     0.134345     0.138615
# 2015-01-02 10:10:00  2065.0  2060.0     0.139675     0.143980
# 2015-01-02 10:20:00  2065.0  2060.0     0.140710     0.144930
#
#                      DaysTo_VX1_Expiry  DaysTo_VX2_Expiry  VX1_Future  \
# 2015-01-02 09:40:00          11.993056          32.993056      17.175
# 2015-01-02 09:50:00          11.986111          32.986111      17.275
# 2015-01-02 10:00:00          11.979167          32.979167      17.375
# 2015-01-02 10:10:00          11.972222          32.972222      17.725
# 2015-01-02 10:20:00          11.965278          32.965278      17.725
#
#                            OPT  VX1-OPT_Spread  VIX_ImpVol  SPX_Index(fwd)
# 2015-01-02 09:40:00  13.940883        3.234117    1.144474      2072.14990
# 2015-01-02 09:50:00  13.831527        3.443473    1.140503      2068.86011
# 2015-01-02 10:00:00  14.099285        3.275715    1.142770      2068.50000
# 2015-01-02 10:10:00  14.637765        3.087235    1.183701      2063.32007
# 2015-01-02 10:20:00  14.728039        2.996961    1.183615      2063.04004

# %% [markdown]
# #### Export/Load primary *master* dataframe to/from a pickle file

# %%
master_mid.to_pickle(filepath + r'\master_mid.pkl')

# %%
master_mid = pd.read_pickle(filepath + r'\master_mid.pkl')

# %% [markdown]
# ### Load & Compile EOD intraday data into one dataframe

# %%
fname_4 = r'\vx1_opt_eod.pkl'
fname_5 = r'\vix_eod_vol_2terms.pkl'
fname_6 = r'\spx_returns_eod.pkl'

filepath = os.getcwd() + r'\Data\Intraday\Pickle'

vx1_opt_eod = pickle.load(open(filepath + fname_4, "rb"))
vix_ivol_eod = pickle.load(open(filepath + fname_5, "rb"))
spx_index_eod = pickle.load(open(filepath + fname_6, "rb"))

# %% [markdown]
# #### Load SPX Options & VIX Futures data

# %%
vx1_opt_eod.head()
# Out:
#                      SPX_Strike1  SPX_Strike2  SPX_Option1  SPX_Option2  \
# TIMESTAMP
# 2015-01-02 16:10:00       2060.0       2055.0     0.132675     0.142680
# 2015-01-02 16:15:00       2060.0       2055.0     0.135100     0.142260
# 2015-01-05 16:10:00       2020.0       2020.0     0.164065     0.161785
# 2015-01-05 16:15:00       2020.0       2020.0     0.166455     0.161440
# 2015-01-06 16:10:00       2005.0       2000.0     0.175230     0.172300
#
#                             t1         t2  FWD_PRICE        OPT  \
# TIMESTAMP
# 2015-01-02 16:10:00  11.722222  32.722222     17.725  14.797089
# 2015-01-02 16:15:00  11.718750  32.718750     17.825  14.610308
# 2015-01-05 16:10:00  10.722222  31.722222     18.925  16.060839
# 2015-01-05 16:15:00  10.718750  31.718750     19.125  15.881923
# 2015-01-06 16:10:00   9.722222  30.722222     19.825  17.092651
#
#                      VX1-OPT_Spread
# TIMESTAMP
# 2015-01-02 16:10:00        2.927911
# 2015-01-02 16:15:00        3.214692
# 2015-01-05 16:10:00        2.864161
# 2015-01-05 16:15:00        3.243077
# 2015-01-06 16:10:00        2.732349

# %% [markdown]
# #### Load VIX Options data

# %%
vix_ivol_eod.head()
# Out:
#                      VIX_Strike1  VIX_Strike2  VIX_Option1  VIX_Option2  \
# TIMESTAMP
# 2015-01-02 16:10:00         19.0         20.0     1.349465     1.094165
# 2015-01-02 16:15:00         19.0         20.0     1.343440     1.085335
# 2015-01-05 16:10:00         20.0         21.0     1.542750     1.192500
# 2015-01-05 16:15:00         20.0         21.0     1.550630     1.192595
# 2015-01-06 16:10:00         21.0         21.0     1.538645     1.153830
#
#                             t1         t2  trade_dates/expiry  Weight_Opt
# TIMESTAMP
# 2015-01-02 16:10:00  11.722222  21.722222                22.0    1.230196
# 2015-01-02 16:15:00  11.718750  21.718750                22.0    1.222820
# 2015-01-05 16:10:00  10.722222  21.722222                22.0    1.363203
# 2015-01-05 16:15:00  10.718750  21.718750                22.0    1.367035
# 2015-01-06 16:10:00   9.722222  21.722222                22.0    1.323887

# %% [markdown]
# #### Load SPX Cash data

# %%
spx_index_eod.head()
# Out:
#                      UPRICE_BID  UPRICE_ASK  UPRICE_MID
# TIMESTAMP
# 2015-01-02 16:10:00  2058.19995  2058.19995  2058.19995
# 2015-01-02 16:15:00  2058.19995  2058.19995  2058.19995
# 2015-01-05 16:10:00  2020.57996  2020.57996  2020.57996
# 2015-01-05 16:15:00  2020.57996  2020.57996  2020.57996
# 2015-01-06 16:10:00  2002.60999  2002.60999  2002.60999

# %% [markdown]
# #### Add Weighted Imp. vol of ATM front month VIX options to VIX futures prices & SPX options approximation to create MASTER EOD dataframe

# %%
master_eod = vx1_opt_eod.merge(vix_ivol_eod.iloc[:,7].to_frame(), left_index=True, right_index=True)

# %%
master_eod.head()
# Out:
#                      SPX_Strike1  SPX_Strike2  SPX_Option1  SPX_Option2  \
# TIMESTAMP
# 2015-01-02 16:10:00       2060.0       2055.0     0.132675     0.142680
# 2015-01-02 16:15:00       2060.0       2055.0     0.135100     0.142260
# 2015-01-05 16:10:00       2020.0       2020.0     0.164065     0.161785
# 2015-01-05 16:15:00       2020.0       2020.0     0.166455     0.161440
# 2015-01-06 16:10:00       2005.0       2000.0     0.175230     0.172300
#
#                             t1         t2  FWD_PRICE        OPT  \
# TIMESTAMP
# 2015-01-02 16:10:00  11.722222  32.722222     17.725  14.797089
# 2015-01-02 16:15:00  11.718750  32.718750     17.825  14.610308
# 2015-01-05 16:10:00  10.722222  31.722222     18.925  16.060839
# 2015-01-05 16:15:00  10.718750  31.718750     19.125  15.881923
# 2015-01-06 16:10:00   9.722222  30.722222     19.825  17.092651
#
#                      VX1-OPT_Spread  Weight_Opt
# TIMESTAMP
# 2015-01-02 16:10:00        2.927911    1.230196
# 2015-01-02 16:15:00        3.214692    1.222820
# 2015-01-05 16:10:00        2.864161    1.363203
# 2015-01-05 16:15:00        3.243077    1.367035
# 2015-01-06 16:10:00        2.732349    1.323887

# %% [markdown]
# #### Rename specific columns

# %%
master_eod.rename(columns={'SPX_Strike1':'SPX_k1', 'SPX_Strike2':'SPX_k2', 'SPX_Option1':'SPX_ImpVol1',\
                           'SPX_Option2':'SPX_ImpVol2','t1':'DaysTo_VX1_Expiry','t2':'DaysTo_VX2_Expiry',\
                           'FWD_PRICE':'VX1_Future', 'Weight_Opt':'VIX_ImpVol'}, inplace=True)

# %%
master_eod.head()
# Out:
#                      SPX_k1  SPX_k2  SPX_ImpVol1  SPX_ImpVol2  \
# TIMESTAMP
# 2015-01-02 16:10:00  2060.0  2055.0     0.132675     0.142680
# 2015-01-02 16:15:00  2060.0  2055.0     0.135100     0.142260
# 2015-01-05 16:10:00  2020.0  2020.0     0.164065     0.161785
# 2015-01-05 16:15:00  2020.0  2020.0     0.166455     0.161440
# 2015-01-06 16:10:00  2005.0  2000.0     0.175230     0.172300
#
#                      DaysTo_VX1_Expiry  DaysTo_VX2_Expiry  VX1_Future  \
# TIMESTAMP
# 2015-01-02 16:10:00          11.722222          32.722222      17.725
# 2015-01-02 16:15:00          11.718750          32.718750      17.825
# 2015-01-05 16:10:00          10.722222          31.722222      18.925
# 2015-01-05 16:15:00          10.718750          31.718750      19.125
# 2015-01-06 16:10:00           9.722222          30.722222      19.825
#
#                            OPT  VX1-OPT_Spread  VIX_ImpVol
# TIMESTAMP
# 2015-01-02 16:10:00  14.797089        2.927911    1.230196
# 2015-01-02 16:15:00  14.610308        3.214692    1.222820
# 2015-01-05 16:10:00  16.060839        2.864161    1.363203
# 2015-01-05 16:15:00  15.881923        3.243077    1.367035
# 2015-01-06 16:10:00  17.092651        2.732349    1.323887

# %% [markdown]
# #### Add intraday SPX Index prices to *master_eod*

# %%
master_eod = master_eod.merge(spx_index_eod.iloc[:,2].to_frame(), left_index=True, right_index=True)

# %%
master_eod.head()
# Out:
#                      SPX_k1  SPX_k2  SPX_ImpVol1  SPX_ImpVol2  \
# TIMESTAMP
# 2015-01-02 16:10:00  2060.0  2055.0     0.132675     0.142680
# 2015-01-02 16:15:00  2060.0  2055.0     0.135100     0.142260
# 2015-01-05 16:10:00  2020.0  2020.0     0.164065     0.161785
# 2015-01-05 16:15:00  2020.0  2020.0     0.166455     0.161440
# 2015-01-06 16:10:00  2005.0  2000.0     0.175230     0.172300
#
#                      DaysTo_VX1_Expiry  DaysTo_VX2_Expiry  VX1_Future  \
# TIMESTAMP
# 2015-01-02 16:10:00          11.722222          32.722222      17.725
# 2015-01-02 16:15:00          11.718750          32.718750      17.825
# 2015-01-05 16:10:00          10.722222          31.722222      18.925
# 2015-01-05 16:15:00          10.718750          31.718750      19.125
# 2015-01-06 16:10:00           9.722222          30.722222      19.825
#
#                            OPT  VX1-OPT_Spread  VIX_ImpVol  UPRICE_MID
# TIMESTAMP
# 2015-01-02 16:10:00  14.797089        2.927911    1.230196  2058.19995
# 2015-01-02 16:15:00  14.610308        3.214692    1.222820  2058.19995
# 2015-01-05 16:10:00  16.060839        2.864161    1.363203  2020.57996
# 2015-01-05 16:15:00  15.881923        3.243077    1.367035  2020.57996
# 2015-01-06 16:10:00  17.092651        2.732349    1.323887  2002.60999

# %% [markdown]
# #### Rename last column

# %%
master_eod.rename(columns={'UPRICE_MID':'SPX_Index(fwd)'}, inplace=True)

# %%
master_eod.head()
# Out:
#                      SPX_k1  SPX_k2  SPX_ImpVol1  SPX_ImpVol2  \
# TIMESTAMP
# 2015-01-02 16:10:00  2060.0  2055.0     0.132675     0.142680
# 2015-01-02 16:15:00  2060.0  2055.0     0.135100     0.142260
# 2015-01-05 16:10:00  2020.0  2020.0     0.164065     0.161785
# 2015-01-05 16:15:00  2020.0  2020.0     0.166455     0.161440
# 2015-01-06 16:10:00  2005.0  2000.0     0.175230     0.172300
#
#                      DaysTo_VX1_Expiry  DaysTo_VX2_Expiry  VX1_Future  \
# TIMESTAMP
# 2015-01-02 16:10:00          11.722222          32.722222      17.725
# 2015-01-02 16:15:00          11.718750          32.718750      17.825
# 2015-01-05 16:10:00          10.722222          31.722222      18.925
# 2015-01-05 16:15:00          10.718750          31.718750      19.125
# 2015-01-06 16:10:00           9.722222          30.722222      19.825
#
#                            OPT  VX1-OPT_Spread  VIX_ImpVol  SPX_Index(fwd)
# TIMESTAMP
# 2015-01-02 16:10:00  14.797089        2.927911    1.230196      2058.19995
# 2015-01-02 16:15:00  14.610308        3.214692    1.222820      2058.19995
# 2015-01-05 16:10:00  16.060839        2.864161    1.363203      2020.57996
# 2015-01-05 16:15:00  15.881923        3.243077    1.367035      2020.57996
# 2015-01-06 16:10:00  17.092651        2.732349    1.323887      2002.60999

# %% [markdown]
# #### Export *master_eod* dataframe to a pickle file

# %%
master_eod.to_pickle(filepath + r'\master_eod.pkl')

# %% [markdown]
# ### Combine primary and EOD master dataframes

# %%
master = master_mid.append(master_eod)

# %% [markdown]
# #### Sort by timestamp (index)

# %%
master.sort_index(inplace=True)

# %%
master.tail()
#master.head(42)
# Out:
#                      SPX_k1  SPX_k2  SPX_ImpVol1  SPX_ImpVol2  \
# 2016-12-30 15:40:00  2240.0  2235.0     0.112185     0.123280
# 2016-12-30 15:50:00  2235.0  2235.0     0.114750     0.123050
# 2016-12-30 16:00:00  2240.0  2240.0     0.112725     0.120915
# 2016-12-30 16:10:00  2240.0  2240.0     0.111685     0.121555
# 2016-12-30 16:15:00  2240.0  2240.0     0.111450     0.121020
#
#                      DaysTo_VX1_Expiry  DaysTo_VX2_Expiry  VX1_Future  \
# 2016-12-30 15:40:00          11.743056          33.743056      15.125
# 2016-12-30 15:50:00          11.736111          33.736111      15.275
# 2016-12-30 16:00:00          11.729167          33.729167      15.125
# 2016-12-30 16:10:00          11.722222          33.722222      15.125
# 2016-12-30 16:15:00          11.718750          33.718750      15.125
#
#                            OPT  VX1-OPT_Spread  VIX_ImpVol  SPX_Index(fwd)
# 2016-12-30 15:40:00  12.881164        2.243836    0.963283      2238.12988
# 2016-12-30 15:50:00  12.725649        2.549351    0.985248      2235.60010
# 2016-12-30 16:00:00  12.506244        2.618756    0.979816      2239.61011
# 2016-12-30 16:10:00  12.649992        2.475008    0.961698      2238.83008
# 2016-12-30 16:15:00  12.582087        2.542913    0.961768      2238.83008

# %%
len(master)
# Out:
# 20250

# %%
master.iloc[:,[2,3,4,5,7,8,9]] = master.iloc[:,[2,3,4,5,7,8,9]].round(4)
master.iloc[:,[10]] = master.iloc[:,[10]].round(2)

# %%
master.tail()
# Out:
#                      SPX_k1  SPX_k2  SPX_ImpVol1  SPX_ImpVol2  \
# 2016-12-30 15:40:00  2240.0  2235.0       0.1122       0.1233
# 2016-12-30 15:50:00  2235.0  2235.0       0.1148       0.1230
# 2016-12-30 16:00:00  2240.0  2240.0       0.1127       0.1209
# 2016-12-30 16:10:00  2240.0  2240.0       0.1117       0.1216
# 2016-12-30 16:15:00  2240.0  2240.0       0.1114       0.1210
#
#                      DaysTo_VX1_Expiry  DaysTo_VX2_Expiry  VX1_Future  \
# 2016-12-30 15:40:00            11.7431            33.7431      15.125
# 2016-12-30 15:50:00            11.7361            33.7361      15.275
# 2016-12-30 16:00:00            11.7292            33.7292      15.125
# 2016-12-30 16:10:00            11.7222            33.7222      15.125
# 2016-12-30 16:15:00            11.7188            33.7188      15.125
#
#                          OPT  VX1-OPT_Spread  VIX_ImpVol  SPX_Index(fwd)
# 2016-12-30 15:40:00  12.8812          2.2438      0.9633         2238.13
# 2016-12-30 15:50:00  12.7256          2.5494      0.9852         2235.60
# 2016-12-30 16:00:00  12.5062          2.6188      0.9798         2239.61
# 2016-12-30 16:10:00  12.6500          2.4750      0.9617         2238.83
# 2016-12-30 16:15:00  12.5821          2.5429      0.9618         2238.83

# %%
master.isna().sum()
# Out:
# SPX_k1               0
# SPX_k2               0
# SPX_ImpVol1          0
# SPX_ImpVol2          0
# DaysTo_VX1_Expiry    0
# DaysTo_VX2_Expiry    0
# VX1_Future           0
# OPT                  0
# VX1-OPT_Spread       0
# VIX_ImpVol           0
# SPX_Index(fwd)       0
# dtype: int64

# %% [markdown]
# #### Export *master* dataframe to a pickle file

# %%
master.to_pickle(filepath + r'\master.pkl')

# %% [markdown]
# #### Export *master* dataframe to a .csv file

# %%
master.to_csv(os.getcwd() + r'\Data\Intraday\VIX_Master_DataFrame.csv')
